# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.117  Python-3.9.16 torch-2.0.1+cpu CPU
# Setup complete  (24 CPUs, 31.9 GB RAM, 560.8/903.5 GB disk)

# %%
from ultralytics import YOLO as yolo

model = yolo('yolov8n.pt')

print(type(model.names), len(model.names))
print(model.names)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 8.07MB/s]
# <class 'dict'> 80
# ...

# %%
model.train(data='C:/Users/User/Desktop/InsectData/ultralytics/data.yaml', epochs=10, patience=30, batch=32)
# Out:
# Ultralytics YOLOv8.0.117  Python-3.9.16 torch-2.0.1+cpu CPU
# ...
